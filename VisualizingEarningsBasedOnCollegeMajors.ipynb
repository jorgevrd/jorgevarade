# %% [markdown]
# ## GUIDED PROJECT: Visualizing Earnings Based On College Majors

# %% [markdown]
# #### 1. Introduction

# %% [markdown]
# In this guided project, we'll explore how using the pandas plotting functionality along with the Jupyter notebook interface allows us to explore data quickly using visualizations.
#
# We'll be working with a dataset on the job outcomes of students who graduated from college between 2010 and 2012. The original data on job outcomes was released by [American Community Survey](https://www.census.gov/programs-surveys/acs/), which conducts surveys and aggregates the data.
#
# Each row in the dataset represents a different major in college and contains information on gender diversity, employment rates, median salaries, and more. Here are some of the columns in the dataset:
# - Rank : Rank by median earnings (the dataset is ordered by this column).
# - Major_code : Major code
# - Major : Major description
# - Major_category : Category of major
# - Total : Total number of people with major
# - Sample_size : sample size of full-time
# - Men : Male graduates
# - Women : Female graduates
# - ShareWomen : Women as share of total
# - Employed : Nmber of employers
# - Median: Median salary of full-time, year-round workers
# - Low_wage_jobs:Number in low-wage service jobs.
# - Full_time:Number employed 35 hours or more.
# - Part_time:Number employed less than 35 hours.

# %% [markdown]
# Before we start creating data visualizations, let's import the libraries we need and remove rows containing null values.

# %% [markdown]
# #### 1.1 Introduction

# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline
recent_grads = pd.read_csv('recent-grads.csv')

# %%
print(recent_grads.iloc[0])
print(recent_grads.head())
print(recent_grads.tail())
print(recent_grads.describe())
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
print(recent_grads.describe())
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count =recent_grads.shape
print(raw_data_count)
# Out:
# (173, 21)

# %%
recent_grads = recent_grads.dropna()
print(recent_grads)
print(recent_grads.shape)
# Out:
#      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 6       7        6202                              ACTUARIAL SCIENCE
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 8       9        2414                         MECHANICAL ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 10     11        2407                           COMPUTER ENGINEERING
# 11     12        2401                          AEROSPACE ENGINEERING
# 12     13        2404                         BIOMEDICAL ENGINEERING
# ...

# %% [markdown]
# We used the function .DROPNA() to drop all the rows containing missing values, and then, we assign it to a new variable 'recent_grads'.
# the difference of ussing this function is only one row less.

# %%
cleaned_data_count = recent_grads.shape
print(cleaned_data_count)
# Out:
# (172, 21)

# %% [markdown]
# As i said before, we get notice that there is one row less. We assign all this cleaned data to a new variable 'cleaned_data_count'

# %% [markdown]
# #### 2. Pandas, scatter plots

# %%
recent_grads.plot(x='Sample_size', y='Median', kind='scatter')

# %%
recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter')

# %%
recent_grads.plot(x='Full_time', y = 'Median', kind='scatter')

# %%
recent_grads.plot(x='ShareWomen', y = 'Unemployment_rate', kind= 'scatter')

# %%
recent_grads.plot(x='Men', y='Median', kind='scatter')

# %%
recent_grads.plot(x='Women', y='Median', kind='scatter')

# %% [markdown]
# #### 3. Pandas, Histograms

# %%
recent_grads['Sample_size'].hist(bins=20, range=(0,5000))

# %%
recent_grads['Median'].hist(bins=1, range=(0,7000))

# %%
recent_grads['Employed'].hist( bins=50, range=(0,5000))

# %%
recent_grads['Full_time'].hist( bins=25, range=(0,5000))

# %%
recent_grads['ShareWomen'].hist( bins=5, range=(0,750))

# %%
recent_grads['Unemployment_rate'].hist( bins=2, range=(0,50))

# %%
recent_grads['Men'].hist( bins=2, range=(0,50))

# %%
recent_grads['Women'].hist( bins=2, range=(0,50))

# %% [markdown]
# #### 4. Pandas, Scatter Matrix Plot

# %%
import pandas
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f741714cf98>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f74176334a8>,
# ...
#       dtype=object)

# %% [markdown]
# ##### 5. Pandas, Bar Plots

# %%
recent_grads['Women'].plot(kind='bar').bins=100

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen', legend=True)
recent_grads[163:].plot.bar(x='Major', y='ShareWomen', legend=True)
